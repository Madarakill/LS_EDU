# %%
# Импорт библиотек

import kagglehub
import os
import shutil
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %matplotlib inline
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 15)

# %%
df = pd.read_csv("leads_1000.csv", low_memory=False)

# %%
df
# Out:
#                               Prospect ID  Lead Number  \
# 0    8e607053-48ff-4548-ac31-b5d55cac99ec       660500
# 1    3576e113-5200-499c-9193-aeabb543507c       660499
# 2    405e32fa-f11e-4003-b455-999069f12bcc       660498
# 3    b6eb0e42-6e3f-4076-82ef-7484123c9af4       660497
# 4    90b3012e-da8a-4b14-81ca-5cc36b96545f       660496
# ..                                    ...          ...
# 995  76dc4845-da7e-451b-9ee5-75bb1fdde6db       659505
# 996  530a1f6d-3842-45a3-8055-d0cc8b1853cc       659504
# 997  be1ace7d-db62-4c6a-b6c8-d33426366db3       659503
# 998  84f40279-61ae-43b5-9d4d-5d066cbb869b       659502
# 999  15fd558b-fd4e-46fb-9923-88606726a4f1       659501
#
#                  Lead Origin       Lead Source Do Not Email Do Not Call  \
# 0              Lead Add Form            Google           No          No
# 1                        API           YouTube           No          No
# 2                        API         Reference           No          No
# 3    Landing Page Submission            Google           No          No
# 4                        API        Olark Chat           No          No
# ..                       ...               ...          ...         ...
# 995           Quick Add Form            Google          Yes          No
# 996              Lead Import            Google           No          No
# 997           Quick Add Form  Welingak Website           No          No
# 998                      API           YouTube          Yes          No
# 999                      API  Welingak Website           No          No
#
#      Converted  ...  Asymmetrique Activity Index  Asymmetrique Profile Index  \
# 0            0  ...                    02.Medium                   02.Medium
# 1            1  ...                    02.Medium                   02.Medium
# 2            0  ...                       03.Low                     01.High
# 3            0  ...                      01.High                     01.High
# 4            0  ...                    02.Medium                     01.High
# ..         ...  ...                          ...                         ...
# 995          0  ...                      01.High                     01.High
# 996          1  ...                    02.Medium                     01.High
# 997          1  ...                       03.Low                     01.High
# 998          0  ...                    02.Medium                   02.Medium
# 999          1  ...                      01.High                   02.Medium
#
#      Asymmetrique Activity Score Asymmetrique Profile Score  \
# 0                             15                         13
# 1                             14                         16
# 2                             11                         15
# 3                             18                         15
# 4                             16                         15
# ..                           ...                        ...
# 995                           16                         16
# 996                           12                         15
# 997                           11                         18
# 998                           13                         16
# 999                           17                         12
#
#     I agree to pay the amount through cheque  \
# 0                                         No
# 1                                        Yes
# 2                                         No
# 3                                         No
# 4                                         No
# ..                                       ...
# 995                                       No
# 996                                       No
# 997                                       No
# 998                                       No
# 999                                       No
#
#     A free copy of Mastering The Interview    Last Notable Activity
# 0                                       No             Email Opened
# 1                                       No  Page Visited on Website
# 2                                       No              Unreachable
# 3                                      Yes              Unreachable
# 4                                       No  Olark Chat Conversation
# ..                                     ...                      ...
# 995                                     No              Unreachable
# 996                                     No                 Modified
# 997                                     No             Email Opened
# 998                                     No             Email Opened
# 999                                     No       Email Link Clicked
#
# [1000 rows x 37 columns]
